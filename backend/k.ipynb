# %%
import pandas as pd
import joblib

# %%
with open("D:\Loan_aproval\Loan_aproval_model\loan_predict.joblib","rb") as f:
    model=joblib.load(f)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\user\AppData\Local\Temp\ipykernel_9236\2768372990.py:1: SyntaxWarning: invalid escape sequence '\L'
#   with open("D:\Loan_aproval\Loan_aproval_model\loan_predict.joblib","rb") as f:

# %%
with open("D:\Loan_aproval\Loan_aproval_model\preprocess.joblib","rb") as fb:
    prepro=joblib.load(fb)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\user\AppData\Local\Temp\ipykernel_9236\4138418007.py:1: SyntaxWarning: invalid escape sequence '\L'
#   with open("D:\Loan_aproval\Loan_aproval_model\preprocess.joblib","rb") as fb:

# %%
len(prepro.get_feature_names_out())
# Out:
# 21

# %%
js={
        "person_age": 22,
    "person_gender": "female",
    "person_education": "Master",
    "person_income": 71948,
    "person_home_ownership":"RENT", 
    "loan_amnt": 35000,
    "loan_intent": "PERSONAL",
    "loan_int_rate": 16.02,
    "cb_person_cred_hist_length": 3,
    "credit_score": 561,
    "previous_loan_defaults_on_file": "No",
    }

jso=pd.DataFrame([js],columns=['person_age', 'person_gender', 'person_education', 'person_income', 'person_home_ownership', 'loan_amnt', 'loan_intent','loan_int_rate', 'cb_person_cred_hist_length','credit_score', 'previous_loan_defaults_on_file'])

# %%
new_data=prepro.transform(jso)

# %%
model.predict_proba(new_data)
# Out:
# array([[3.8987398e-04, 9.9961013e-01]], dtype=float32)
